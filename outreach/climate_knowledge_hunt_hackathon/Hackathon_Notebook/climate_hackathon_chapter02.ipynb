# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayathrijonnalagadda/Demo/blob/main/outreach/climate_knowledge_hunt_hackathon/Hackathon_Notebook/climate_hackathon_chapter02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Install packages
# ![image.png](data:image/png;base64,...)
# **To install packages run the cell below... This may take 4 min or so**
#
#
# ---
# <hr height=3>

# %% [markdown]
# To run a cell please follow this figure. Mainly you have to click the play button....
#
#
# ![image.png](data:image/png;base64,...)

# %%
#installing the tools
# !git clone  https://github.com/petermr/semanticClimate.git
# !pip install -r /content/semanticClimate/keyword_extraction/code/requirement.txt
# !pip install docanalysis
# !pip install py4ami==0.0.35
# !python -m spacy download en_core_web_lg
import nltk
nltk.download('stopwords')
# Out:
# fatal: destination path 'semanticClimate' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/LIAAD/yake (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2))
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-1yo70_r9
#   Running command git clone --filter=blob:none --quiet https://github.com/LIAAD/yake /tmp/pip-req-build-1yo70_r9
#   Resolved https://github.com/LIAAD/yake to commit 374fc1c1c19eb080d5b6115cbb8d4a4324392e54
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: multi_rake in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (0.0.2)
# Requirement already satisfied: summa in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 3)) (1.2.0)
# Requirement already satisfied: keybert in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.7.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (1.5.3)
# Requirement already satisfied: tkinterhtml==0.7 in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 6)) (0.7)
# Requirement already satisfied: pyamiimage in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.0.13)
# Requirement already satisfied: pdfplumber==0.7.4 in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (0.7.4)
# Requirement already satisfied: pdfminer3 in /usr/local/lib/python3.9/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (2018.12.3.0)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.9/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (9.5.0)
# Requirement already satisfied: pdfminer.six==20220524 in /usr/local/lib/python3.9/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (20220524)
# Requirement already satisfied: Wand>=0.6.7 in /usr/local/lib/python3.9/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (0.6.11)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (2.0.12)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.9/dist-packages (from pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (40.0.2)
# Requirement already satisfied: numpy>=1.14.4 in /usr/local/lib/python3.9/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (1.22.4)
# Requirement already satisfied: pyrsistent>=0.14.2 in /usr/local/lib/python3.9/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (0.19.3)
# Requirement already satisfied: regex>=2018.6.6 in /usr/local/lib/python3.9/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (2022.10.31)
# Requirement already satisfied: pycld2>=0.41 in /usr/local/lib/python3.9/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (0.41)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (0.8.10)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.9/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (8.1.3)
# Requirement already satisfied: segtok in /usr/local/lib/python3.9/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (1.5.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (3.1)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.9/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (0.11.2)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.9/dist-packages (from summa->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 3)) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.9/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.2.2)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.9/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.2.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.9/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (13.3.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (2.8.2)
# Requirement already satisfied: skan in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.11.0)
# Requirement already satisfied: sknw in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.14)
# Requirement already satisfied: easyocr in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.6.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.9.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (7.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.19.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (67.7.1)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.9/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.3.10)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.9/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (3.17)
# Requirement already satisfied: chardet in /usr/local/lib/python3.9/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (4.0.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.9/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.2.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.0.0+cu118)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.14.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.1.98)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.65.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.28.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.8.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.15.1+cu118)
# Requirement already satisfied: ninja in /usr/local/lib/python3.9/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.11.1)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in /usr/local/lib/python3.9/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.5.4.60)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.9/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.3.0.post4)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.9/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (6.0)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.9/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.39.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (23.1.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2023.4.12)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.25.1)
# Requirement already satisfied: numba>=0.50 in /usr/local/lib/python3.9/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.56.4)
# Requirement already satisfied: openpyxl>=2.4 in /usr/local/lib/python3.9/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.0.10)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=36.0.0->pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (1.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.50->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.39.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl>=2.4->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.1.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.13.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting docanalysis
#   Using cached docanalysis-0.2.0-py3-none-any.whl (37 kB)
# Collecting tkinterweb==3.10.7
#   Using cached tkinterweb-3.10.7.tar.gz (1.1 MB)
#   Preparing metadata (setup.py) ... done
# Collecting braceexpand==0.1.7
#   Using cached braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting nltk==3.6.7
#   Using cached nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Collecting ConfigArgParse==1.5.3
#   Using cached ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Collecting pandas==1.3.4
#   Using cached pandas-1.3.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# Collecting pygetpapers
#   Using cached pygetpapers-1.2.5-py3-none-any.whl (111 kB)
# Collecting scispacy==0.4.0
#   Using cached scispacy-0.4.0-py3-none-any.whl (44 kB)
# Collecting setuptools==60.3.1
#   Using cached setuptools-60.3.1-py3-none-any.whl (953 kB)
# Collecting coloredlogs==15.0.1
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting spacy==3.0.7
#   Using cached spacy-3.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
# Requirement already satisfied: py4ami in /usr/local/lib/python3.9/dist-packages (from docanalysis) (0.0.35)
# Collecting lxml==4.7.1
#   Using cached lxml-4.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
# Collecting abbreviations
#   Using cached abbreviations-0.2.5-py3-none-any.whl (5.7 kB)
# Collecting pytest==6.2.5
#   Using cached pytest-6.2.5-py3-none-any.whl (280 kB)
# Collecting beautifulsoup4==4.10.0
#   Using cached beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting tqdm==4.62.3
#   Using cached tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4==4.10.0->docanalysis) (2.4.1)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk==3.6.7->docanalysis) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk==3.6.7->docanalysis) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk==3.6.7->docanalysis) (2022.10.31)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.3.4->docanalysis) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.3.4->docanalysis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.3.4->docanalysis) (2022.7.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest==6.2.5->docanalysis) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest==6.2.5->docanalysis) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest==6.2.5->docanalysis) (23.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from pytest==6.2.5->docanalysis) (23.1)
# Collecting py>=1.8.2
#   Using cached py-1.11.0-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from pytest==6.2.5->docanalysis) (0.10.2)
# Collecting nmslib>=1.7.3.6
#   Using cached nmslib-2.1.1-cp39-cp39-manylinux2010_x86_64.whl (13.3 MB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scispacy==0.4.0->docanalysis) (2.27.1)
# Collecting conllu
#   Using cached conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting pysbd
#   Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.9/dist-packages (from scispacy==0.4.0->docanalysis) (1.2.2)
# Collecting thinc<8.1.0,>=8.0.3
#   Using cached thinc-8.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (668 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Using cached typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (0.10.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (0.7.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (2.0.8)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (3.0.12)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Using cached pydantic-1.8.2-cp39-cp39-manylinux2014_x86_64.whl (11.3 MB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (2.4.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy==3.0.7->docanalysis) (2.0.7)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from tkinterweb==3.10.7->docanalysis) (9.5.0)
# Collecting habanero
#   Downloading habanero-1.2.3-py2.py3-none-any.whl (30 kB)
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting arxiv
#   Downloading arxiv-1.4.7-py3-none-any.whl (12 kB)
# Collecting dict2xml
#   Downloading dict2xml-1.7.3-py3-none-any.whl (7.3 kB)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from nmslib>=1.7.3.6->scispacy==0.4.0->docanalysis) (5.9.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from pathy>=0.3.5->spacy==3.0.7->docanalysis) (6.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy==3.0.7->docanalysis) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.4->docanalysis) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.0.0->scispacy==0.4.0->docanalysis) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.0.0->scispacy==0.4.0->docanalysis) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.0.0->scispacy==0.4.0->docanalysis) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.0.0->scispacy==0.4.0->docanalysis) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.3->scispacy==0.4.0->docanalysis) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.3->scispacy==0.4.0->docanalysis) (1.10.1)
# Collecting click
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 9.0 MB/s eta 0:00:00
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy==3.0.7->docanalysis) (2.1.2)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: tkinterweb, sgmllib3k
#   Building wheel for tkinterweb (setup.py) ... done
#   Created wheel for tkinterweb: filename=tkinterweb-3.10.7-py3-none-any.whl size=1063351 sha256=5efeb65a7c74256ed41662b1d9d145cf584f39fd00a33f7b4458486d7e99c211
#   Stored in directory: /root/.cache/pip/wheels/60/60/e2/bddc1324caa7e1ecf06e5a472624acdbf586529a672c00ffb0
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=86ace32fc7259f90e7a9aad8dc818e49fff9b8e7c58ab81c1b21651023b7dee8
#   Stored in directory: /root/.cache/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built tkinterweb sgmllib3k
# Installing collected packages: wasabi, sgmllib3k, braceexpand, xmltodict, tqdm, tkinterweb, setuptools, pysbd, pydantic, pybind11, py, lxml, humanfriendly, feedparser, dict2xml, conllu, ConfigArgParse, click, beautifulsoup4, abbreviations, typer, thinc, pytest, pandas, nmslib, nltk, habanero, coloredlogs, arxiv, pygetpapers, spacy, scispacy, docanalysis
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.1
#     Uninstalling wasabi-1.1.1:
#       Successfully uninstalled wasabi-1.1.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.1
#     Uninstalling setuptools-67.7.1:
#       Successfully uninstalled setuptools-67.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.7
#     Uninstalling pydantic-1.10.7:
#       Successfully uninstalled pydantic-1.10.7
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.2
#     Uninstalling lxml-4.9.2:
#       Successfully uninstalled lxml-4.9.2
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.9
#     Uninstalling thinc-8.1.9:
#       Successfully uninstalled thinc-8.1.9
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.2.2
#     Uninstalling pytest-7.2.2:
#       Successfully uninstalled pytest-7.2.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.2
#     Uninstalling spacy-3.5.2:
#       Successfully uninstalled spacy-3.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# yfinance 0.2.18 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.10.0 which is incompatible.
# yfinance 0.2.18 requires lxml>=4.9.1, but you have lxml 4.7.1 which is incompatible.
# plotnine 0.10.1 requires pandas>=1.3.5, but you have pandas 1.3.4 which is incompatible.
# mizani 0.8.1 requires pandas>=1.3.5, but you have pandas 1.3.4 which is incompatible.
# inflect 6.0.4 requires pydantic>=1.9.1, but you have pydantic 1.8.2 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 1.3.4 which is incompatible.
# flask 2.2.3 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# en-core-web-sm 3.5.0 requires spacy<3.6.0,>=3.5.0, but you have spacy 3.0.7 which is incompatible.
# en-core-web-lg 3.5.0 requires spacy<3.6.0,>=3.5.0, but you have spacy 3.0.7 which is incompatible.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 60.3.1 which is incompatible.
# Successfully installed ConfigArgParse-1.5.3 abbreviations-0.2.5 arxiv-1.4.7 beautifulsoup4-4.10.0 braceexpand-0.1.7 click-7.1.2 coloredlogs-15.0.1 conllu-4.5.2 dict2xml-1.7.3 docanalysis-0.2.0 feedparser-6.0.10 habanero-1.2.3 humanfriendly-10.0 lxml-4.7.1 nltk-3.6.7 nmslib-2.1.1 pandas-1.3.4 py-1.11.0 pybind11-2.6.1 pydantic-1.8.2 pygetpapers-1.2.5 pysbd-0.3.4 pytest-6.2.5 scispacy-0.4.0 setuptools-60.3.1 sgmllib3k-1.0.0 spacy-3.0.7 thinc-8.0.17 tkinterweb-3.10.7 tqdm-4.62.3 typer-0.3.2 wasabi-0.10.1 xmltodict-0.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: py4ami==0.0.35 in /usr/local/lib/python3.9/dist-packages (0.0.35)
# 2023-04-25 04:48:17.512331: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl#egg=en_core_web_lg==3.0.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.8/778.8 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from en-core-web-lg==3.0.0) (3.0.7)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.27.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (23.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (60.3.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.22.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.17)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.7.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (6.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2022.12.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.1.2)
# Installing collected packages: en-core-web-lg
#   Attempting uninstall: en-core-web-lg
#     Found existing installation: en-core-web-lg 3.5.0
#     Uninstalling en-core-web-lg-3.5.0:
#       Successfully uninstalled en-core-web-lg-3.5.0
# Successfully installed en-core-web-lg-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ***Please Dont forget to restart runtime after running the previous cell, else the newly installed packages won't run properly***

# %% [markdown]
# ## Conversion ---> pdf to html

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# **In order to unlock a pdf into an HTML, you just have to click on the cell run below...This takes less than a min to run...**

# %%
import os
import shutil

chapter_no ='Chapter15'
saving_path_html = f'/content/Pdf_to_html_{chapter_no}/'
if not os.path.exists(saving_path_html+'final/'):
  os.makedirs(saving_path_html+'final/')
if not os.path.exists(saving_path_html+'temp/'):
  os.makedirs(saving_path_html+'temp/')  

print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %%
# pdf to html conversion
# !py4ami PDF\
--inpath '/content/semanticClimate/ipcc/ar6/wg3/Chapter15/fulltext.pdf'\
--outpath '/content/Pdf_to_html_Chapter15/final/fulltext.html'\
--outdir  '/content/Pdf_to_html_Chapter15/temp/'\
--pages 1_11

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/py4ami", line 5, in <module>
#     from py4ami.pyamix import main
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/pyamix.py", line 17, in <module>
#     from py4ami.ami_convert import ConvType, Converters
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_convert.py", line 11, in <module>
#     from py4ami.ami_gui import Gutil
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_gui.py", line 19, in <module>
#     from py4ami.search_lib import AmiSearch, AmiSection, AmiDictionaries, AmiProjects
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/search_lib.py", line 25, in <module>
#     from py4ami.ami_project import AmiProjects
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_project.py", line 15, in <module>
#     from py4ami.ami_sections import AMIFigure, AMIAbsSection
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_sections.py", line 6, in <module>
#     from py4ami.xml_lib import XmlLib
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/xml_lib.py", line 8, in <module>
#     from py4ami.file_lib import FileLib
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/file_lib.py", line 4, in <module>
#     from braceexpand import braceexpand
# ModuleNotFoundError: No module named 'braceexpand'
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the output here: **/content/semanticClimate/ipcc/ar6/wg3/Chapter02/fulltext.html**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Abbreviations extraction
#
# ![image.png](data:image/png;base64,...)
# **To extract abbreviation, just run the cell below...It takes a min or so...**

# %%
#making directory to store and obtain the dictionaries 
saving_path = f'/content/wiki_hack/{chapter_no}/sections/0_mainbody/'
if not os.path.exists(saving_path):
  os.makedirs(saving_path)
shutil.copy(f'/content/semanticClimate/ipcc/ar6/wg3/{chapter_no}/fulltext.html',f'/content/wiki_hack/{chapter_no}/sections/0_mainbody')

print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %%
#abbreviation extraction --automated abbreviation using docanalysis
# !docanalysis --project_name '/content/wiki_hack' --output 'entities.csv' --make_ami_dict 'entities.xml'
# structuring the dictionary
# !docanalysis --project_name '/content/wiki_hack'\
--output 'Indexing.csv' --make_json 'Indexing.json'\
--make_ami_dict 'entities' --extract_abb 'abb_chapter15'

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# /bin/bash: docanalysis: command not found
# /bin/bash: docanalysis: command not found
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the output of abbreviation extraction here: **/content/wiki_hack/abb_chapter02.xml**
#
# You can't see the file within colab enviornmnet. Therefore follow th epath and download the file and open in your respective system.
#
# Follow this picture to understand how to download a file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Keywords/ Key-Phrases Extraction
#
# ![image.png](data:image/png;base64,...)
# **To get keywords and key-phrases extracted run the cell below...It take a min or two......**

# %%
# keyword/ phrases extraction
# !python /content/semanticClimate/keyword_extraction/code/keyword_extraction.py \
--html_path /content/wiki_hack/Chapter15/sections/0_mainbody/fulltext.html \
--saving_path /content/ \
--method 'gensim'
print('\033[1;32m We have successfully finished running this cell.')
# Out:
# 2023-04-25 06:01:52.521278: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  We have successfully finished running this cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# You can find the output of Keyword/key-phrases extraction here: **/content/gensim_keywords.csv**

# %% [markdown]
# A demonstration on how to look into CSV/HTML files on your right side of the notebbok:
#
# ![image.png](data:image/png;base64,...)

# %%
# WordCloud Generation
# !python /content/semanticClimate/wordCloud_Generation/SemanticClimate_wordcloud.py\
--file_path '/content/semanticClimate/wordCloud_Generation/'\
--saving_path '/content/'\
--Chapter_name 'Chapter15'

import cv2
from PIL import Image
from google.colab.patches import cv2_imshow
img = cv2.imread(f'/content/{chapter_no}_word_cloud.jpg', cv2.IMREAD_COLOR)
cv2_imshow(img)


#print('\033[1;32m We have successfully finished running this cell.')
# Out:
# Figure(1300x900)
# <PIL.Image.Image image mode=RGB size=1541x785 at 0x7F4EE40E6AC0>

# %% [markdown]
# ##HTML Markup and Annotation
# ![image.png](data:image/png;base64,...)
# **To Markup the HTML please click on the cell bellow..This also takes a min to run...**

# %%
# HTM markup using abbreviation dictionary + manual dictionary + keyword/phrases 
# !py4ami HTML --annotate\
--dict /content/wiki_hack/abb_chapter15.xml\
--inpath /content/semanticClimate/ipcc/ar6/wg3/Chapter15/fulltext.html\
--outpath /content/annotated_fulltext_Chapter15.html\
--color YELLOW

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/py4ami", line 5, in <module>
#     from py4ami.pyamix import main
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/pyamix.py", line 17, in <module>
#     from py4ami.ami_convert import ConvType, Converters
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_convert.py", line 11, in <module>
#     from py4ami.ami_gui import Gutil
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_gui.py", line 19, in <module>
#     from py4ami.search_lib import AmiSearch, AmiSection, AmiDictionaries, AmiProjects
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/search_lib.py", line 25, in <module>
#     from py4ami.ami_project import AmiProjects
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_project.py", line 15, in <module>
#     from py4ami.ami_sections import AMIFigure, AMIAbsSection
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/ami_sections.py", line 6, in <module>
#     from py4ami.xml_lib import XmlLib
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/xml_lib.py", line 8, in <module>
#     from py4ami.file_lib import FileLib
#   File "/usr/local/lib/python3.9/dist-packages/py4ami/file_lib.py", line 4, in <module>
#     from braceexpand import braceexpand
# ModuleNotFoundError: No module named 'braceexpand'
#  We have successfully finished running this cell.

# %%
from tqdm import tqdm
from bs4 import BeautifulSoup
#from keybert import KeyBERT
from multi_rake import Rake
from summa import keywords
import re
import json
import yake
# !pip install gensim==3.6.0
from gensim.summarization import keywords
from IPython.display import HTML
import pandas as pd
import requests
import os
import argparse
import spacy

from transformers import (
    TokenClassificationPipeline,
    AutoModelForTokenClassification,
    AutoTokenizer,
)
from transformers.pipelines import AggregationStrategy
import numpy as np
#import os
#os.environ['TRANSFORMERS_CACHE'] = 'E:\git\transformer_cache'

nlp = spacy.load("en_core_web_lg")


class keyword_extraction():
    def __init__(self, html_path, saving_path, method):
        self.html_path = html_path
        self.saving_path = saving_path
        self.method = method
        self.text = ''
        self.span_list = []

    
    def read_text_from_html(self):
        """uses beautifulsoup to read text from html files

        
        :returns: raw text from html
        :rtype: string

        """
        with open(self.html_path, encoding="utf-8") as f:
            content = f.read()
            soup = BeautifulSoup(content, 'html.parser')
            
            print(type(soup))
        self.soup = soup    
        
        
                #print(self.text)
        return self.soup
    
    def clean_up_html_to_text(self):
        self.extract_text_fom_html()
        #splitlines = self.soup.splitlines()
        #print(splitlines)
        #self.splitlines = splitlines
        
        print(type(self.text.splitlines()))

        '''with open(self.saving_path + 'text.txt', 'w', encoding="utf-8") as file:
                #text = self.text.replace("Final Government Distribution  Chapter 5 IPCC AR6 WGIII", "").replace("Final Government Distribution Chapter 5 IPCC AR6 WGIII", "")
                for line in tqdm(self.splitlines):
                    file.write(line)
                    
                print("Done Writing File")'''
        #return self.splitlines
               

    def extract_span_list(self):
        with open(self.html_path, 'r') as f:
            html = f.read()
            soup = BeautifulSoup(html, features="html.parser")
            with open('/content/semanticClimate/ipcc/ar6/wg3/Chapter15/fulltext.html', 'w', encoding="utf-8") as file:
                file.write(soup.prettify())
            # kill all script and style elements

            soup_elem = soup.find_all("span")
            for span_elem in soup_elem:
                # print(span_elem)
                span_elem.extract()
                span_text = span_elem.get_text().strip()
                lines = (line.strip() for line in span_text.splitlines())
                # break multi-headlines into a line each
                chunks = (phrase.strip() for line in lines for phrase in line.split("  ") if len(phrase.strip()) > 9)
                # drop blank lines
                # text_write = '\n'.join(chunk for chunk in chunks if chunk)
                span_text = ' '.join(chunk for chunk in chunks if chunk)
                if len(span_text) > 9 and 'http' not in span_text and 'doi' not in span_text and 'Chapter' not in span_text:
                    # print(span_text)
                    # print('-'*50)
                    self.span_list.append(span_text)
        return self.span_list
        # def tf_idf(self):

    '''def clean_text(self):
        self.extract_text_fom_html()
        f = self.text
        clean_t = self.text.replace("Paris Agreement Chapter15 IPCC AR6 WGIII", "")
        return self.clean_t'''

    def clean(self, df):
        def tagger(x):
            return nlp(x)[0].pos_

        def lemma(x):
            # print(nlp(x)[0].lemma_)
            return nlp(x)[0].lemma_

        df['POS'] = df['keyword/phrase'].apply(lambda x: tagger(x))
        df['Lemma'] = df['keyword/phrase'].apply(lambda x: lemma(x))
        df = df[df['keyword/phrase'] == df['Lemma']]
        df = df.drop_duplicates(subset=['score'], keep='last')
        df = df[df.POS.isin(['NOUN', 'PROPN', 'ADJ', 'ADV'])]
        df = df[~df['keyword/phrase'].apply(lambda x: lemma(x)).isin(['http', 'https', 'publication', 'Chapter'])]
        df = df.drop(columns=['Lemma'], axis=0)
        return df

    def extract_text_fom_html(self):

        with open(self.html_path, 'r') as f:
            html = f.read()
            soup = BeautifulSoup(html, features="html.parser")

            for script in soup(["script", "style"]):
                script.extract()  # rip it out

            # get text
            text = soup.get_text()
            # print(text)
            # break into lines and remove leading and trailing space on each
            lines = (line.strip() for line in text.splitlines())
            # break multi-headlines into a line each
            chunks = (phrase.strip() for line in lines for phrase in line.split("      ") if len(phrase.strip()) > 9)
            # drop blank lines
            # text_write = '\n'.join(chunk for chunk in chunks if chunk)
            text = '\n '.join(chunk for chunk in chunks if chunk)
            self.text = text
            # print(text)
            # TEXT_ = f'Chapter06_text.txt'
            # saving_path = '/content/'
            with open(self.saving_path + 'text.txt', 'w', encoding="utf-8") as file:
                text = self.text.replace("Paris agreement Chapter15 AR6 WGIII", "").replace("Paris agreement Chapter15 AR6 WGIII", "")
                file.write(text)
                print("Done Writing File")
                #print(self.text)
            return self.text

    def extract_text_fom_file(self):

        with open(self.text_file, 'r') as f:
            textv2 = f.read()

    def extract_keywords_rake(self):
        rake = Rake()
        self.extract_text_fom_html()
        keywords_Rake = rake.apply(self.text)
        df_Rake = pd.DataFrame(keywords_Rake)
        df_Rake.rename(columns={0: 'keyword/phrase', 1: 'score'}, inplace=True)
        df_Rake = self.clean(df_Rake)
        df_Rake.to_csv(self.saving_path + 'Rake_keywords.csv', index=None)

    def extract_keywords_gensim(self):
        self.extract_text_fom_html()
        keywords_gensim = keywords(self.text, words=100, scores=True, pos_filter=('NN', 'ADJ'), lemmatize=False,
                                   deacc=False)  # run over all parameters
        df_gensim = pd.DataFrame(keywords_gensim)
        df_gensim.rename(columns={0: 'keyword/phrase', 1: 'score'}, inplace=True)
        df_gensim = self.clean(df_gensim)
        df_gensim.to_csv(self.saving_path + 'gensim_keywords.csv', index=None)

    def extract_keywords_yake(self):
        self.extract_text_fom_html()
        kw_extractor = yake.KeywordExtractor(top=100, stopwords=None, )
        keywords_yake = kw_extractor.extract_keywords(self.text)
        df_yake =pd.DataFrame(keywords_yake)
        df_yake.rename(columns = {0:'keyword/phrase',1:'score'}, inplace = True)
        #df_yake = self.clean(df_yake)
        df_yake['keyword/phrase'].to_csv(self.saving_path +'yake_keywords.csv',index=None) 

    def extract_keywords_textrank(self):
        self.extract_text_fom_html()
        keywords_textrank = keywords.keywords(self.text, scores=True)
        df_textrank = pd.DataFrame(keywords_textrank)
        df_textrank.rename(columns={0: 'keyword/phrase', 1: 'score'}, inplace=True)
        df_textrank = self.clean(df_textrank)
        df_textrank.to_csv(self.saving_path + 'textrank_keywords.csv', index=None)

    def extract_keywords_keyBERT(self):
        self.extract_text_fom_html()
        kw_model = KeyBERT(model='all-mpnet-base-v2')
        keywords_keyBERT = kw_model.extract_keywords(self.text,
                                                     keyphrase_ngram_range=(1, 3),
                                                     stop_words='english',

                                                     top_n=100)
        print(keywords_keyBERT)
    
    def extract_keywords_hf(self):
        self.keyphrases = []
        self.clean_up_html_to_text()
        model_name = "ml6team/keyphrase-extraction-kbir-inspec"
        for line in tqdm(self.text.splitlines()):
            #print(line)

            extractor = KeyphraseExtractionPipeline(model=model_name)
            keyphrases = extractor(line)
            for i in keyphrases:
                self.keyphrases.append(i)
            #print(self.keyphrases)
        self.keyphrases = [*set(self.keyphrases)]
        df = pd.DataFrame(self.keyphrases)
        df.to_csv(self.saving_path + 'keyphrases.csv' ,index=False)
        return self.keyphrases
    
    def extraction_unigrams(self):

        df = pd.read_csv('Chapter15_keyphrases.csv')
        key = df['0'].tolist()
        unigram =[]
        ngram = []

        pattern = "\s"
        print(type(key))
        for i in key:
            if re.findall(pattern, i):
                ngram.append(i)
                #print('N-gram')
            else:
                unigram.append(i)
                #print('Unigram')
        #print(ngram)
        #print(unigram)
        #self.unigram = unigram
        print(len(unigram))
        return unigram
        #print(len(ngram))

    def wikidata_out(self):
        #list = self.extraction_unigrams()
        list = ['data']#, 'Finance', 'adaptation']
        #list = self.unigram
        
        for i in list:
            self.wiki_lookup(i)
            json_object = json.dumps(self.result, indent=4)
            with open(self.saving_path + 'wikidata.txt', 'w', encoding="utf-8") as file:
                with open("sample.json", "w") as outfile:

                    outfile.write(json_object)


            

    

    def wiki_lookup(self, query):
        """Queries Wikidata API for Wikidata Item IDs for terms in ami-dict

        :param query: term to query wikdiata for ID
        :type query: string
        :returns: potential Wikidata Item URLs
        :rtype: list

        """
        params = {
            "action": "wbsearchentities",
            "search": query,
            "language": "en",
            "format": "json",
            "wbsprofile": "language"
        }
        data = requests.get(
            "https://www.wikidata.org/w/api.php", params=params)
        result = data.json()
        hit_list = []
        self.result = result
        for hit in result['search']:
            try:
                if "scientific article" not in hit["description"]:
                    hit_list.append(hit["id"])
            except:
                hit_list2.append(hit["id"])
        return hit_list



    def main(self):
        if method == 'rake':
            self.extract_keywords_rake()
        elif method == 'yake':
            self.extract_keywords_yake()
        elif method == 'gensim':
            self.extract_keywords_gensim()
        elif method == 'textrank':
            self.extract_keywords_textrank()
        elif method == 'keyBERT':
            self.extract_keywords_keyBERT()
        elif method == 'hf':
            self.extract_keywords_hf()
        elif method == 'rawtext':
            self.wikidata_out()
        else :
            self.extract_keywords_hf()
        
class KeyphraseExtractionPipeline(TokenClassificationPipeline):
    def __init__(self, model, *args, **kwargs):
        super().__init__(
            model=AutoModelForTokenClassification.from_pretrained(model),
            tokenizer=AutoTokenizer.from_pretrained(model),
            *args,
            **kwargs
        )

    def postprocess(self, model_outputs):
        results = super().postprocess(
            model_outputs=model_outputs,
            aggregation_strategy=AggregationStrategy.SIMPLE,
        )
        return np.unique([result.get("word").strip() for result in results])
    



if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('-i', '--html_path',
                        required=False,
                        help='give the path where your html lives: /...')

    parser.add_argument('-t', '--text_file',
                        required=False,
                        help='path to textfile: /...')

    parser.add_argument('-s', '--saving_path',
                        required=True,
                        help='path of the folder where you want to save the files : /...'
                        )
    parser.add_argument('-m', '--method',
                        required=False, choices=['rake', 'yake', 'gensim', 'keyBERT', 'textrank', 'rawtext', 'hf'],
                        help='which method you want to us to extact keywords /...')
    parser.add_argument('--n_gram',
                        required=False,
                        type=int,
                        default=2,
                        help='length of n-grams to extract(Yake only) : /...'
                        )
    parser.add_argument('--html2text',
                        required=False,
                        action='store_true',
                        help='Converts HTML to TXT : /...'
                        )

    #args = parser.parse_args()
    args, unknown = parser.parse_known_args()

    html_path = args.html_path  # '/content/semanticClimate/ipcc/ar6/wg3/Chapter15/fulltext.html'
    saving_path = args.saving_path  # '/content/'
    method = args.method
    n_gram = args.n_gram
    text_file = args.text_file

    keyword_extractions = keyword_extraction(html_path, saving_path, method)
    keyword_extractions.main()
    if args.html2text:
        keyword_extractions.read_text_from_html()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim==3.6.0 in /usr/local/lib/python3.9/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from gensim==3.6.0) (1.16.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from gensim==3.6.0) (1.22.4)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.9/dist-packages (from gensim==3.6.0) (6.3.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.9/dist-packages (from gensim==3.6.0) (1.10.1)
# usage: ipykernel_launcher.py [-h] [-i HTML_PATH] [-t TEXT_FILE] -s SAVING_PATH
#                              [-m {rake,yake,gensim,keyBERT,textrank,rawtext,hf}]
#                              [--n_gram N_GRAM] [--html2text]
# ipykernel_launcher.py: error: the following arguments are required: -s/--saving_path
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %% [markdown]
# You can find the ouput of HTML Markup and annotation chuck here: **/content/annotated_fulltext_Chapter02.html**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
